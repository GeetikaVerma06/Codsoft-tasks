# %% [markdown]
# # Prediction of survival rate on titanic dataset

# %% [markdown]
# ## Column description
#
# - **PassengerId:** This is a unique number provided to every guest. It functions similarly to an ID number in tracking everyone.
#
# - **Survived:** This tells us whether the passenger survived the Titanic accident. A 0 signifies they did not survive, while a 1 means they did.
#
# - **Pclass:** This represents the class of the passenger's ticket. There are three classes: the first, second, and third class. First class was the most luxury, while third class was the least expensive.
# - **Name:** This is the passenger's full name.
# - **Sex:** This identifies the passenger's gender, whether male or female.
# - **Age:** This is the passenger's age in years. Some ages may be missing because they were not recorded.
# - **SibSp:** This refers to siblings/spouses living abroad. It indicates how many siblings or spouses the passenger had aboard the Titanic.
# - **Parch:** This is for parents/children on board. It indicates how many parents or children accompanied the guest on the voyage.
# - **Ticket:** This is the ticket number used by the traveler to board the Titanic.
# - **Fare:** This is the amount of money the passenger paid for the ticket.
# - **Cabin:** This is the stateroom number where the passenger stayed on the ship. Many travelers have no documented cabin number.
# - **Embarked:** This is the port where passengers boarded the Titanic. The ports are: C = Cherbourg. Q = Queenstown. S denotes Southampton.

# %% [markdown]
# # Importing the necessary libraries

# %%
#Here we are importing the libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#Reading the titanic dataset
df=pd.read_csv("C:/CodSoft/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Exploring data in depth

# %%
#Shows the dimensions of the given dataset i.e. rows and columns
df.shape
# Out:
# (891, 12)

# %%
#Displays all the columns names present in the dataset
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Shows the datatype of the columns
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Shows the count of the data present in it. It shows not empty values
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
#Checks if the data present is null. Here we can see that all columns have 'False' value which means the data doesn't have any
#NULL values present in it
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#Checking if there are missing values in dataset
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# replacing the missing values in "Age" column with mean value
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
# replacing the missing values in "Embarked" column with mode value
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
# check the number of missing values in each column
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Printing first 10 values of the dataset
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
#Returns bottom 10 values by default
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#Provides a concise summary of the dataframe with null count and its datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Gives statistical information of the data
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Shows the count of males and females who clicked on the advertisement
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # EDA of the data

# %%
#Plots a histogram and giving the size of the figure width=20 and height=20
df.hist(figsize = (20,20))
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
#Shows the pairplot of the passenger who survived or not
sn.pairplot(df, hue = 'Survived', palette= 'cool')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = df.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='cool', linewidths=0.5)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6068\1264571724.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
#Plotting boxplot of PClass and Age
plt.figure(figsize=(10,7))
sn.boxplot(x='Pclass',y='Age',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#plotting a bar plot for SibSp survived
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='SibSp', hue='Survived')
plt.title('Survival Rate by Number of Siblings/Spouses')
plt.show()

# %%
#Plot for Survival rate by age
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='Survived', y='Age')
plt.title('Survival Rate by Age')
plt.show()

# %%
# Plot Survival Rate by Passenger Class
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Survival Rate by Passenger Class')
plt.show()

# %%
#Plotting fare distribution
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Fare', kde=True)
plt.title('Fare Distribution of Passengers')
plt.show()

# %%
# Plot Age distribution of passengers
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Age', kde=True)
plt.title('Age Distribution of Passengers')
plt.show()

# %%
#Dropping the 'Cabin' column from the dataframe
df.drop(['Cabin'], axis=1, inplace=True)

# %%
#Dropping the 'Cabin' column from the dataframe
df.drop(['PassengerId'], axis=1, inplace=True)

# %%
# converting categorical Columns
df.replace({'Sex':{'male':0,'female':1}, 'Embarked':{'S':0,'C':1,'Q':2}}, inplace=True)
df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
#Copying data so that original dataset is not affected
data = df[['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Age', 'Fare']].copy(deep= True)

# %%
# importing train test model and loading independent variables to x and dependent variables to y
from sklearn.model_selection import train_test_split
x = data[['Pclass', 'Sex', 'Parch', 'Age','Fare']]
y = data['Survived']

# %%
# assigning variables in train test split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
# importing classification models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# KNeighbhors algorithm where we have kept value of k in a loop to get an optimum value with least misclassified data
missclassified=[]
for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    kpred = knn.predict(x_test)
    missclassified.append((y_test != kpred).sum())
print(missclassified)
# Out:
# [90, 86, 79, 89, 79, 87, 77, 80, 83, 85, 80, 80, 81, 85, 88, 84, 90, 88, 92]

# %%
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(x_train,y_train)
kpred = knn.predict(x_test)
kcm = confusion_matrix(y_test,kpred)
kacc = accuracy_score(y_test,kpred)
print(f'The confusion matrix is:\n{kcm}\nThe accuracy is: {round((kacc*100), 2)}%')
# Out:
# The confusion matrix is:
# [[135  18]
#  [ 69  46]]
# The accuracy is: 67.54%

# %%
# Logistic Regression algorithm
lr = LogisticRegression()
lr.fit(x_train,y_train)
lpred = lr.predict(x_test)
lcm = confusion_matrix(y_test,lpred)
lacc = accuracy_score(y_test,lpred)
print(f'The confusion matrix is:\n{lcm}\nThe accuracy is: {lacc*100}%')
# Out:
# The confusion matrix is:
# [[131  22]
#  [ 36  79]]
# The accuracy is: 78.35820895522389%

# %%
# Decision Tree algorithm
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dpred = dtc.predict(x_test)
dcm = confusion_matrix(y_test,dpred)
dacc = accuracy_score(y_test,dpred)
print(f'The confusion matrix is:\n{dcm}\nThe accuracy is: {dacc*100}%')
# Out:
# The confusion matrix is:
# [[128  25]
#  [ 44  71]]
# The accuracy is: 74.25373134328358%

# %%
# Random Forest algorithm
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
rpred = rfc.predict(x_test)
rcm = confusion_matrix(y_test,rpred)
racc = accuracy_score(y_test,rpred)
print(f'The confusion matrix is:\n{rcm}\nThe accuracy is: {racc*100}%')
# Out:
# The confusion matrix is:
# [[138  15]
#  [ 42  73]]
# The accuracy is: 78.73134328358209%

# %%
# Naives Bayes - Gaussian theorem algorithm
nb = GaussianNB()
nb.fit(x_train,y_train)
npred = nb.predict(x_test)
ncm = confusion_matrix(y_test,npred)
nacc = accuracy_score(y_test,npred)
print(f'The confusion matrix is:\n{ncm}\nThe accuracy is: {nacc*100}%')
# Out:
# The confusion matrix is:
# [[123  30]
#  [ 36  79]]
# The accuracy is: 75.3731343283582%

# %%
# Scalar Vector Machine algorithm
svm = SVC(kernel='linear',random_state=12)
svm.fit(x_train,y_train)
spred = svm.predict(x_test)
scm = confusion_matrix(y_test,spred)
sacc = accuracy_score(y_test,spred)
print(f'The confusion matrix is:\n{scm}\nThe accuracy is: {sacc*100}%')
# Out:
# The confusion matrix is:
# [[129  24]
#  [ 42  73]]
# The accuracy is: 75.3731343283582%
